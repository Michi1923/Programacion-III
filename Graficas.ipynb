# %% [markdown]
# <a href="https://colab.research.google.com/github/Michi1923/Programacion-III/blob/Graficas/Graficas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarjetas de crédito: por sexo (cuenta)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-029fbc30-6141-4dce-a2e3-34e25735e8a9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-029fbc30-6141-4dce-a2e3-34e25735e8a9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tarjetas_por_sexo.csv to tarjetas_por_sexo (1).csv

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

totalDlsTipo = pd.read_csv("/content/tarjetas_por_sexo.csv", sep=";", encoding="utf-8")
print(totalDlsTipo)

labels = ['Gender']
men_means = [12372]
women_means = [13680]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/1, men_means, width, label='Masculino')
rects2 = ax.bar(x + width/1, women_means, width, label='Femenino')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_title('Frecuencia')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


fig.tight_layout()

plt.show()
# Out:
#   Gender  Total
# 0      F  13680
# 1      M  12372

# %% [markdown]
# # Tarjetas de crédito por ciudad

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e517cdf5-6ec8-41dd-a9ea-5a44d7381d66" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e517cdf5-6ec8-41dd-a9ea-5a44d7381d66">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving total_dls_ciudad_tipo_tarjeta.csv to total_dls_ciudad_tipo_tarjeta.csv

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 12), subplot_kw=dict(aspect="equal"))

recipe = ["17.5 % Achalpur,India,Gold",
          "0.5 % Achalpur,India,Platinum",
          "12.5 % Achalpur,India,Signature",
          "3.5 % Achalpur,India,Silver",
          
          "24.0 % Achalpur,India,Gold",
          "17.1 % Achalpur,India,Platinum",
          "1.3 % Achalpur,India,Signature",
          "5.2 % Achalpur,India,Silver",
          
          "14.1 % Achalpur,India,Gold",
          "4.6 % Achalpur,India,Platinum"]          

data = [float(x.split()[0]) for x in recipe]
ingredients = [x.split()[-1] for x in recipe]


def func(pct, allvals):
    absolute = int(round(pct/100.*np.sum(allvals)))
    return "{:1.1f}%".format(pct, absolute)


wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="black"))

ax.legend(wedges, ingredients,
          title="Ciudades y Tipo de Tarjetas",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=12, weight="bold")

ax.set_title("Tipo de Tarjetas por Ciudades")

plt.show()

# %% [markdown]
# #Tipo de gasto

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fd9e1897-0bcc-4ab5-a7e9-52c1130c18d4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd9e1897-0bcc-4ab5-a7e9-52c1130c18d4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving total_dls_tipo_gasto.csv to total_dls_tipo_gasto (1).csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
archivo = pd.read_csv("/content/total_dls_tipo_gasto.csv",sep=";",encoding="utf-8")
#print(archivo, archivo["Exp Type"])

procesar = pd.crosstab(index=archivo["Exp Type"],columns="sum")
print(procesar)

plt.pie(procesar, labels=procesar.index)
plt.xlabel("Exp Type")
plt.show()
# Out:
# col_0          sum
# Exp Type
# Bills            1
# Entertainment    1
# Food             1
# Fuel             1
# Grocery          1
# Travel           1
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   if __name__ == '__main__':
